# %% [markdown]
# Importin modules in Python
#
# in Python,modules and packages help organize and reuse code.Here's a comprehensive guid on how to import them

# %%
import math
math.sqrt(16)

# %%
from math import sqrt,pi
print(sqrt(16))
print(pi)

# %%
import numpy as np

# %%
from math import* 
sqrt(19)
# Out:
# 4.358898943540674

# %%
from package.maths import addition
