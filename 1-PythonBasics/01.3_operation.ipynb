# %%
##Operation

a=11
b=5

floor_div_result=a//b## for integer result
modulus_result=a%b##remainder
exponent_result=a**b##eponent

print(floor_div_result)
print(modulus_result)
print(exponent_result)
# Out:
# 2
# 1
# 161051

# %% [markdown]
# ####Logical Operators

# %%
##And,Not,Or
X=True
Y=False

Result_and= X and Y
Result_or = X or Y
print(Result_and)
print(Result_or)
print(not X)
# Out:
# False
# True
# False
