# %%
1+1
# Out:
# 2

# %%
print("Hello WORLD")
# Out:
# Hello WORLD

# %%
##Indentation
age=32
if(age>30):
   print(age)


print(age)
# Out:
# 32
# 32

# %%
##Line continuation
total=1+2+3+4+5+\
5+6+7
print(total)
# Out:
# 33

# %%
##Multiple statrment on single line
x=5;y=10;z=x+y
print(z)
# Out:
# 15

# %%
##Sematics
#variable assignment
age=32 
name="Krish"

# %%
type(name)
# Out:
# str

# %%
##type inference
variable=10
print(type(variable))
variable="Krish"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>
